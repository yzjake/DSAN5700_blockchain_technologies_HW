# %% [markdown]
# ## Assignment 02 – Cryptocurrency Portfolio
#
# #### Group 7
# #### jake
# #### Sirui Xie sx115
# #### Congfei Yin cy478
# Please use jupyter notebook to implement the following structures. You will upload a Jupyter Notebook and an HTML or a PDF file (exported from the notebook) to the canvas portal. There is no restriction on what IDE to use, but a cloud IDE like Google Collab or AWS Sagemaker would be your best choice if you have a low-power/configuration computer. All the assignments are graded holistically. All assignments in the class are group assignments (if you prefer, you can choose to work independently).
#
# This assignment will be graded out of 75 points. Each assignment submission page lists assignment open and close dates with grace periods (48 hours). They are also listed on the syllabus.
#
# Since Blockchain is open-sourced, you will find most of the code online with a complete solution to most assignments. Please refrain from copy-pasting. The goal is to learn to build one from scratch to understand the technology. I will keep an eye on the submissions. Please list the source after the code to avoid plagiarism and copying issues.
#
# The entire assignment is recorded and posted on Canvas under Panopto. You should go over the video and modify the code accordingly.
#
# ### 1       Importing data and packages

# %%
import pandas_datareader.data as pdr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import requests
plt.style.use('bmh')

# %% [markdown]
# ### 2       Gather Coin token ID information from Coinmarket, Binance, or Coinbase.

# %% [markdown]
# You will need to search on any of the three websites to get the token IDs. The video shows how to do it through Binance and coin market cap. A slight difference between the Binance token and the coin market token is that the Binance token adds BUSD or USDT at the end, while the CoinMarket token does not. For example, Bitcoin is represented as BTC in CoinMarket and BTCBUSD or BTCUSDT in Binance. This represents the currency conversion to a stablecoin instead of a fiat currency.
#
# For the sake of this bit, you can choose any 30 cryptocurrencies except Bitcoin and Ethereum. Here are the categories to select from

# %% [markdown]
# 1. High market cap group - this will include the most widely traded coins. We will use the top 5 coins, namely, Bitcoin (BTC-USD), Ethereum (ETH-USD), Litecoin (LTC-USD), Teather (USDT), and BNB (BNB-USD).

# %%
high_market_cap = ['BTC','ETH','USDT','LTC','USDT','BNB']

# %% [markdown]
# 2. Mid-market cap group will include coins with a market cap between 1 billion and 20 billion. We will use the top 5 coins, namely, Cardano (ADA-USD), Polygon (MATIC-USD), Dogecoin (DOGE-USD), Ripple (XRP-USD), and Binance USD (BUSD).

# %%
mid_market_cap = ['ADA','MATIC','DOGE','XRP','BUSD']

# %% [markdown]
# 3. The low market cap group will include coins with a market cap between 100 million and 1 billion. We will use the top 20 coins.
# Make sure to list the ticker ids in a list of strings

# %%
low_market_cap = ['GRT','ALGO','USDD','STX','EOS','EGLD','INJ','FRAX','RNDR','NEO','AXS','XEC','GT','CETH','USDP','FLOW','APE','KCS','CHZ','IOTA']

# %% [markdown]
# #### 2.1        Getting Data From Binance
# Create a function that takes ticker interval, start_time, and end_time as input. We want to get all the data for the selected tickers and save them in data chosen frames. There is a way to automate this by using a function as well.
#
# 1. For each coin/token, you will get a dataframe of daily movements from start to end. The date and time are set as the index. Close, Symbol, and index are the most critical columns, and we want to subset them in a" coins" dataframe for all the coins.

# %% [markdown]
# Here, we use coingecko to grab the coin data. Based on the above 30 coins from coin market cap, we adjust the coin_id to use for coingecko api. And for the below calculation, we select the time interval from 2023-06-27 to 2023-09-27

# %%
from time import sleep

def get_coin_data(coin_id, from_timestamp, to_timestamp, currency='usd'):
    base_url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range"
    params = {
        'vs_currency': currency,
        'from': from_timestamp,
        'to': to_timestamp
    }

    response = requests.get(base_url, params=params)
    response.raise_for_status()

    data = response.json()
    df = pd.DataFrame(data['prices'], columns=['Date', 'Close'])
    df['Date'] = pd.to_datetime(df['Date'], unit='ms')
    df.set_index('Date', inplace=True)
    df['Symbol'] = coin_id.upper()
    
    return df

# %%
tokens = high_market_cap + mid_market_cap + low_market_cap
coin_id=['bitcoin','ethereum','litecoin','tether','binancecoin','cardano','matic-network','dogecoin','ripple','binance-usd','the-graph','algorand','usdd','blockstack','eos','elrond-erd-2','injective-protocol','frax','render-token','neo','axie-infinity','ecash','gatechain-token','compound-ether','paxos-standard','flow','apecoin','kucoin-shares','chiliz','iota']

start_time = int(pd.Timestamp('2023-06-27').timestamp())
end_time = int(pd.Timestamp('2023-09-27').timestamp())

# %%
all_coins = []

for i in range(len(coin_id)):

    coin_data = get_coin_data(coin_id[i], start_time, end_time)
    all_coins.append(coin_data)
    sleep(30)
  # Sleep for 60 seconds to respect API rate limits

# %%
# Sandbox website has different format, so we deall with it seperately
coin_id = "the-sandbox"
if coin_id:
        coin_data = get_coin_data(coin_id, start_time, end_time)
        all_coins.append(coin_data)
        sleep(60)  # Sleep for 60 seconds to respect API rate limits
else:
        print(f"Failed to get data for symbol: {symbol}")
coins = pd.concat(all_coins)

# %%
coins.head()
# Out:
#                    Close   Symbol
# Date
# 2023-06-27  30285.505064  BITCOIN
# 2023-06-28  30693.546356  BITCOIN
# 2023-06-29  30083.477245  BITCOIN
# 2023-06-30  30466.610457  BITCOIN
# 2023-07-01  30480.781482  BITCOIN

# %% [markdown]
# 2. Rename close to "Coinname_closeprice." Replace the coin name with the name of the coin and token id.

# %% [markdown]
# #### 2.2        Combining the dataframe
# The updated dataframe should have the index and close price of all the coins of interest. We will use this to calculate the efficient frontier for the portfolio.

# %%
Symbol = coins['Symbol'].unique()

# %%
coins_df = None
for i in range(30):
    symbol = Symbol[i]
    coin_name = tokens[i]
    coin_df = coins[coins['Symbol'] == symbol]
    new_col_name = f"{symbol}_{coin_name}_closeprice"
    coin_df.rename(columns={'Close': new_col_name}, inplace=True)
    coin_df.drop(columns=['Symbol'], inplace=True)
    if coins_df is None:
        coins_df = coin_df
    else:
        coins_df = coins_df.merge(coin_df,how = 'left', left_index=True, right_index=True)
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
coins_df.head()
# Out:
#             BITCOIN_BTC_closeprice  ETHEREUM_ETH_closeprice  \
# Date
# 2023-06-27            30285.505064              1859.802420
# 2023-06-28            30693.546356              1890.012904
# 2023-06-29            30083.477245              1828.458336
# 2023-06-30            30466.610457              1853.445246
# 2023-07-01            30480.781482              1934.045714
#
#             LITECOIN_USDT_closeprice  TETHER_LTC_closeprice  \
# Date
# 2023-06-27                 87.242862               1.000250
# 2023-06-28                 87.971243               0.999820
# 2023-06-29                 83.090666               0.999451
# 2023-06-30                 84.855730               1.000383
# 2023-07-01                107.962168               0.999596
#
#             BINANCECOIN_USDT_closeprice  CARDANO_BNB_closeprice  \
# Date
# 2023-06-27                   236.170319                0.280616
# 2023-06-28                   237.496341                0.286364
# 2023-06-29                   230.498040                0.266987
# 2023-06-30                   233.406202                0.275736
# 2023-07-01                   240.515441                0.286846
#
#             MATIC-NETWORK_ADA_closeprice  DOGECOIN_MATIC_closeprice  \
# Date
# 2023-06-27                      0.645300                   0.064770
# 2023-06-28                      0.664397                   0.065546
# 2023-06-29                      0.614389                   0.062562
# 2023-06-30                      0.624204                   0.063458
# 2023-07-01                      0.660604                   0.066438
#
#             RIPPLE_DOGE_closeprice  BINANCE-USD_XRP_closeprice  ...  \
# Date                                                            ...
# 2023-06-27                0.479150                    1.000565  ...
# 2023-06-28                0.484370                    0.999037  ...
# 2023-06-29                0.464818                    0.998411  ...
# 2023-06-30                0.474588                    1.000003  ...
# 2023-07-01                0.473648                    0.999740  ...
#
#             AXIE-INFINITY_NEO_closeprice  ECASH_AXS_closeprice  \
# Date
# 2023-06-27                      5.800973              0.000024
# 2023-06-28                      5.892852              0.000024
# 2023-06-29                      5.531489              0.000022
# 2023-06-30                      5.657325              0.000023
# 2023-07-01                      5.938318              0.000040
#
#             GATECHAIN-TOKEN_XEC_closeprice  COMPOUND-ETHER_GT_closeprice  \
# Date
# 2023-06-27                        4.240039                     37.349704
# 2023-06-28                        4.247014                     37.928411
# 2023-06-29                        4.202539                     36.697418
# 2023-06-30                        4.222562                     37.178836
# 2023-07-01                        4.307001                     38.824020
#
#             PAXOS-STANDARD_CETH_closeprice  FLOW_USDP_closeprice  \
# Date
# 2023-06-27                        1.000394              0.540887
# 2023-06-28                        1.000239              0.545379
# 2023-06-29                        1.000099              0.508966
# 2023-06-30                        1.000045              0.517462
# 2023-07-01                        0.998574              0.542773
#
#             APECOIN_FLOW_closeprice  KUCOIN-SHARES_APE_closeprice  \
# Date
# 2023-06-27                 2.325061                      6.539588
# 2023-06-28                 2.316848                      6.568144
# 2023-06-29                 2.198929                      6.403128
# 2023-06-30                 2.236530                      6.415872
# 2023-07-01                 2.222757                      6.594385
#
#             CHILIZ_KCS_closeprice  IOTA_CHZ_closeprice
# Date
# 2023-06-27               0.077383             0.180039
# 2023-06-28               0.077503             0.183843
# 2023-06-29               0.072630             0.174586
# 2023-06-30               0.074128             0.177849
# 2023-07-01               0.075688             0.182127
#
# [5 rows x 30 columns]

# %%
# Here we replace the NaN of BRIDGED-TETHER-LINEA to 0 as its launch date is 2023-08-14.
coins_df.fillna(0, inplace=True)

# %%
coins_df.head()
# Out:
#             BITCOIN_BTC_closeprice  ETHEREUM_ETH_closeprice  \
# Date
# 2023-06-27            30285.505064              1859.802420
# 2023-06-28            30693.546356              1890.012904
# 2023-06-29            30083.477245              1828.458336
# 2023-06-30            30466.610457              1853.445246
# 2023-07-01            30480.781482              1934.045714
#
#             LITECOIN_USDT_closeprice  TETHER_LTC_closeprice  \
# Date
# 2023-06-27                 87.242862               1.000250
# 2023-06-28                 87.971243               0.999820
# 2023-06-29                 83.090666               0.999451
# 2023-06-30                 84.855730               1.000383
# 2023-07-01                107.962168               0.999596
#
#             BINANCECOIN_USDT_closeprice  CARDANO_BNB_closeprice  \
# Date
# 2023-06-27                   236.170319                0.280616
# 2023-06-28                   237.496341                0.286364
# 2023-06-29                   230.498040                0.266987
# 2023-06-30                   233.406202                0.275736
# 2023-07-01                   240.515441                0.286846
#
#             MATIC-NETWORK_ADA_closeprice  DOGECOIN_MATIC_closeprice  \
# Date
# 2023-06-27                      0.645300                   0.064770
# 2023-06-28                      0.664397                   0.065546
# 2023-06-29                      0.614389                   0.062562
# 2023-06-30                      0.624204                   0.063458
# 2023-07-01                      0.660604                   0.066438
#
#             RIPPLE_DOGE_closeprice  BINANCE-USD_XRP_closeprice  ...  \
# Date                                                            ...
# 2023-06-27                0.479150                    1.000565  ...
# 2023-06-28                0.484370                    0.999037  ...
# 2023-06-29                0.464818                    0.998411  ...
# 2023-06-30                0.474588                    1.000003  ...
# 2023-07-01                0.473648                    0.999740  ...
#
#             AXIE-INFINITY_NEO_closeprice  ECASH_AXS_closeprice  \
# Date
# 2023-06-27                      5.800973              0.000024
# 2023-06-28                      5.892852              0.000024
# 2023-06-29                      5.531489              0.000022
# 2023-06-30                      5.657325              0.000023
# 2023-07-01                      5.938318              0.000040
#
#             GATECHAIN-TOKEN_XEC_closeprice  COMPOUND-ETHER_GT_closeprice  \
# Date
# 2023-06-27                        4.240039                     37.349704
# 2023-06-28                        4.247014                     37.928411
# 2023-06-29                        4.202539                     36.697418
# 2023-06-30                        4.222562                     37.178836
# 2023-07-01                        4.307001                     38.824020
#
#             PAXOS-STANDARD_CETH_closeprice  FLOW_USDP_closeprice  \
# Date
# 2023-06-27                        1.000394              0.540887
# 2023-06-28                        1.000239              0.545379
# 2023-06-29                        1.000099              0.508966
# 2023-06-30                        1.000045              0.517462
# 2023-07-01                        0.998574              0.542773
#
#             APECOIN_FLOW_closeprice  KUCOIN-SHARES_APE_closeprice  \
# Date
# 2023-06-27                 2.325061                      6.539588
# 2023-06-28                 2.316848                      6.568144
# 2023-06-29                 2.198929                      6.403128
# 2023-06-30                 2.236530                      6.415872
# 2023-07-01                 2.222757                      6.594385
#
#             CHILIZ_KCS_closeprice  IOTA_CHZ_closeprice
# Date
# 2023-06-27               0.077383             0.180039
# 2023-06-28               0.077503             0.183843
# 2023-06-29               0.072630             0.174586
# 2023-06-30               0.074128             0.177849
# 2023-07-01               0.075688             0.182127
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 3       Calculating the Efficient Frontier
# To calculate an efficient frontier, we will need to calculate each coin's means, standard deviations, and covariances.
#
# 1. Calculate the mean of the dataframe generated in 2.2 using pd.df.mean() method

# %%
def calc_mean(df):
    return df.mean()

coin_mean = calc_mean(coins_df)
print(coin_mean)
# Out:
# BITCOIN_BTC_closeprice                28263.885521
# ETHEREUM_ETH_closeprice                1769.281003
# LITECOIN_USDT_closeprice                 79.464777
# TETHER_LTC_closeprice                     0.999752
# BINANCECOIN_USDT_closeprice             229.586652
# CARDANO_BNB_closeprice                    0.279711
# MATIC-NETWORK_ADA_closeprice              0.631771
# DOGECOIN_MATIC_closeprice                 0.067525
# RIPPLE_DOGE_closeprice                    0.571903
# BINANCE-USD_XRP_closeprice                1.000008
# THE-GRAPH_BUSD_closeprice                 0.101523
# ALGORAND_GRT_closeprice                   0.106060
# USDD_ALGO_closeprice                      0.998255
# BLOCKSTACK_USDD_closeprice                0.558606
# EOS_STX_closeprice                        0.666771
# ELROND-ERD-2_EOS_closeprice              29.792218
# INJECTIVE-PROTOCOL_EGLD_closeprice        7.703602
# FRAX_INJ_closeprice                       0.998127
# RENDER-TOKEN_FRAX_closeprice              1.682608
# NEO_RNDR_closeprice                       8.147451
# AXIE-INFINITY_NEO_closeprice              5.416695
# ECASH_AXS_closeprice                      0.000028
# GATECHAIN-TOKEN_XEC_closeprice            4.069519
# COMPOUND-ETHER_GT_closeprice             35.537966
# PAXOS-STANDARD_CETH_closeprice            1.000026
# FLOW_USDP_closeprice                      0.525314
# APECOIN_FLOW_closeprice                   1.695116
# KUCOIN-SHARES_APE_closeprice              5.286904
# CHILIZ_KCS_closeprice                     0.069657
# IOTA_CHZ_closeprice                       0.168591
# dtype: float64

# %% [markdown]
# 2. Calculate the covariance matrix of the dataframe generated in 2.2 using pd.df.cov() method

# %%
def calc_cov(df):
    return df.cov()

coin_cov = calc_cov(coins_df)
print(coin_cov)
# Out:
#                                     BITCOIN_BTC_closeprice  \
# BITCOIN_BTC_closeprice                        3.522930e+06
# ETHEREUM_ETH_closeprice                       2.273125e+05
# LITECOIN_USDT_closeprice                      2.665245e+04
# TETHER_LTC_closeprice                         1.458214e-01
# BINANCECOIN_USDT_closeprice                   2.470270e+04
# CARDANO_BNB_closeprice                        3.961869e+01
# MATIC-NETWORK_ADA_closeprice                  1.496550e+02
# DOGECOIN_MATIC_closeprice                     6.671179e+00
# RIPPLE_DOGE_closeprice                        8.616405e+01
# BINANCE-USD_XRP_closeprice                    1.649855e-01
# THE-GRAPH_BUSD_closeprice                     2.350034e+01
# ALGORAND_GRT_closeprice                       1.827784e+01
# USDD_ALGO_closeprice                          1.607647e+00
# BLOCKSTACK_USDD_closeprice                    1.579464e+02
# EOS_STX_closeprice                            1.465806e+02
# ELROND-ERD-2_EOS_closeprice                   7.858527e+03
# INJECTIVE-PROTOCOL_EGLD_closeprice            1.056700e+03
# FRAX_INJ_closeprice                           1.208576e+00
# RENDER-TOKEN_FRAX_closeprice                  3.961672e+02
# NEO_RNDR_closeprice                           1.592155e+03
# AXIE-INFINITY_NEO_closeprice                  1.299799e+03
# ECASH_AXS_closeprice                          6.742531e-03
# GATECHAIN-TOKEN_XEC_closeprice                3.300535e+02
# COMPOUND-ETHER_GT_closeprice                  4.572411e+03
# PAXOS-STANDARD_CETH_closeprice                6.851408e-01
# FLOW_USDP_closeprice                          1.419427e+02
# APECOIN_FLOW_closeprice                       6.397953e+02
# KUCOIN-SHARES_APE_closeprice                  1.595798e+03
# CHILIZ_KCS_closeprice                         1.577749e+01
# IOTA_CHZ_closeprice                           2.094310e+01
#
#                                     ETHEREUM_ETH_closeprice  \
# BITCOIN_BTC_closeprice                        227312.460938
# ETHEREUM_ETH_closeprice                        15596.283046
# LITECOIN_USDT_closeprice                        1780.639716
# TETHER_LTC_closeprice                              0.007082
# BINANCECOIN_USDT_closeprice                     1696.609483
# CARDANO_BNB_closeprice                             2.884111
# MATIC-NETWORK_ADA_closeprice                      10.507487
# DOGECOIN_MATIC_closeprice                          0.505617
# RIPPLE_DOGE_closeprice                             7.040080
# BINANCE-USD_XRP_closeprice                         0.011540
# THE-GRAPH_BUSD_closeprice                          1.593874
# ALGORAND_GRT_closeprice                            1.183331
# USDD_ALGO_closeprice                               0.101180
# BLOCKSTACK_USDD_closeprice                        10.232878
# EOS_STX_closeprice                                10.070248
# ELROND-ERD-2_EOS_closeprice                      525.982148
# INJECTIVE-PROTOCOL_EGLD_closeprice                73.694620
# FRAX_INJ_closeprice                                0.084253
# RENDER-TOKEN_FRAX_closeprice                      24.735111
# NEO_RNDR_closeprice                              104.751804
# AXIE-INFINITY_NEO_closeprice                      90.228733
# ECASH_AXS_closeprice                               0.000450
# GATECHAIN-TOKEN_XEC_closeprice                    22.120481
# COMPOUND-ETHER_GT_closeprice                     313.227230
# PAXOS-STANDARD_CETH_closeprice                     0.054206
# FLOW_USDP_closeprice                               9.639586
# APECOIN_FLOW_closeprice                           44.453386
# KUCOIN-SHARES_APE_closeprice                     104.375700
# CHILIZ_KCS_closeprice                              1.092071
# IOTA_CHZ_closeprice                                1.425124
#
#                                     LITECOIN_USDT_closeprice  \
# BITCOIN_BTC_closeprice                          26652.445149
# ETHEREUM_ETH_closeprice                          1780.639716
# LITECOIN_USDT_closeprice                          222.505515
# TETHER_LTC_closeprice                               0.001379
# BINANCECOIN_USDT_closeprice                       190.674655
# CARDANO_BNB_closeprice                              0.314660
# MATIC-NETWORK_ADA_closeprice                        1.174641
# DOGECOIN_MATIC_closeprice                           0.052126
# RIPPLE_DOGE_closeprice                              0.642290
# BINANCE-USD_XRP_closeprice                          0.001467
# THE-GRAPH_BUSD_closeprice                           0.188411
# ALGORAND_GRT_closeprice                             0.139697
# USDD_ALGO_closeprice                                0.013392
# BLOCKSTACK_USDD_closeprice                          1.226398
# EOS_STX_closeprice                                  1.166554
# ELROND-ERD-2_EOS_closeprice                        62.130253
# INJECTIVE-PROTOCOL_EGLD_closeprice                  8.679747
# FRAX_INJ_closeprice                                 0.010337
# RENDER-TOKEN_FRAX_closeprice                        3.109554
# NEO_RNDR_closeprice                                12.763061
# AXIE-INFINITY_NEO_closeprice                       10.300284
# ECASH_AXS_closeprice                                0.000059
# GATECHAIN-TOKEN_XEC_closeprice                      2.677125
# COMPOUND-ETHER_GT_closeprice                       35.794438
# PAXOS-STANDARD_CETH_closeprice                      0.005039
# FLOW_USDP_closeprice                                1.176894
# APECOIN_FLOW_closeprice                             5.002083
# KUCOIN-SHARES_APE_closeprice                       12.534036
# CHILIZ_KCS_closeprice                               0.123400
# IOTA_CHZ_closeprice                                 0.170163
#
#                                     TETHER_LTC_closeprice  \
# BITCOIN_BTC_closeprice                       1.458214e-01
# ETHEREUM_ETH_closeprice                      7.081936e-03
# LITECOIN_USDT_closeprice                     1.379479e-03
# TETHER_LTC_closeprice                        3.948148e-07
# BINANCECOIN_USDT_closeprice                  3.979949e-04
# CARDANO_BNB_closeprice                       2.480990e-06
# MATIC-NETWORK_ADA_closeprice                 8.233890e-06
# DOGECOIN_MATIC_closeprice                   -2.843159e-07
# RIPPLE_DOGE_closeprice                       5.989941e-06
# BINANCE-USD_XRP_closeprice                   2.150674e-07
# THE-GRAPH_BUSD_closeprice                    1.210346e-06
# ALGORAND_GRT_closeprice                      7.248253e-07
# USDD_ALGO_closeprice                         5.346452e-07
# BLOCKSTACK_USDD_closeprice                   8.221180e-06
# EOS_STX_closeprice                           5.624813e-06
# ELROND-ERD-2_EOS_closeprice                  4.874973e-04
# INJECTIVE-PROTOCOL_EGLD_closeprice           9.975475e-05
# FRAX_INJ_closeprice                          1.309071e-07
# RENDER-TOKEN_FRAX_closeprice                 3.782829e-05
# NEO_RNDR_closeprice                          1.023360e-04
# AXIE-INFINITY_NEO_closeprice                 4.691562e-05
# ECASH_AXS_closeprice                         2.859483e-10
# GATECHAIN-TOKEN_XEC_closeprice               2.041210e-05
# COMPOUND-ETHER_GT_closeprice                 1.408327e-04
# PAXOS-STANDARD_CETH_closeprice               1.741272e-07
# FLOW_USDP_closeprice                         6.944230e-06
# APECOIN_FLOW_closeprice                      7.918036e-06
# KUCOIN-SHARES_APE_closeprice                 6.814789e-05
# CHILIZ_KCS_closeprice                        3.729803e-07
# IOTA_CHZ_closeprice                          2.157407e-06
#
#                                     BINANCECOIN_USDT_closeprice  \
# BITCOIN_BTC_closeprice                             24702.699857
# ETHEREUM_ETH_closeprice                             1696.609483
# LITECOIN_USDT_closeprice                             190.674655
# TETHER_LTC_closeprice                                  0.000398
# BINANCECOIN_USDT_closeprice                          195.067299
# CARDANO_BNB_closeprice                                 0.327036
# MATIC-NETWORK_ADA_closeprice                           1.177787
# DOGECOIN_MATIC_closeprice                              0.062174
# RIPPLE_DOGE_closeprice                                 0.872509
# BINANCE-USD_XRP_closeprice                             0.001900
# THE-GRAPH_BUSD_closeprice                              0.171791
# ALGORAND_GRT_closeprice                                0.124425
# USDD_ALGO_closeprice                                   0.011113
# BLOCKSTACK_USDD_closeprice                             1.078695
# EOS_STX_closeprice                                     1.124193
# ELROND-ERD-2_EOS_closeprice                           56.082030
# INJECTIVE-PROTOCOL_EGLD_closeprice                     7.997544
# FRAX_INJ_closeprice                                    0.008721
# RENDER-TOKEN_FRAX_closeprice                           2.579168
# NEO_RNDR_closeprice                                   11.390722
# AXIE-INFINITY_NEO_closeprice                           9.951916
# ECASH_AXS_closeprice                                   0.000049
# GATECHAIN-TOKEN_XEC_closeprice                         2.342755
# COMPOUND-ETHER_GT_closeprice                          34.032261
# PAXOS-STANDARD_CETH_closeprice                         0.007135
# FLOW_USDP_closeprice                                   1.051069
# APECOIN_FLOW_closeprice                                4.685825
# KUCOIN-SHARES_APE_closeprice                          10.923334
# CHILIZ_KCS_closeprice                                  0.120770
# IOTA_CHZ_closeprice                                    0.153291
#
#                                     CARDANO_BNB_closeprice  \
# BITCOIN_BTC_closeprice                        3.961869e+01
# ETHEREUM_ETH_closeprice                       2.884111e+00
# LITECOIN_USDT_closeprice                      3.146603e-01
# TETHER_LTC_closeprice                         2.480990e-06
# BINANCECOIN_USDT_closeprice                   3.270356e-01
# CARDANO_BNB_closeprice                        6.398977e-04
# MATIC-NETWORK_ADA_closeprice                  2.180381e-03
# DOGECOIN_MATIC_closeprice                     1.154326e-04
# RIPPLE_DOGE_closeprice                        2.078787e-03
# BINANCE-USD_XRP_closeprice                    4.652408e-06
# THE-GRAPH_BUSD_closeprice                     3.002165e-04
# ALGORAND_GRT_closeprice                       1.990882e-04
# USDD_ALGO_closeprice                          2.102255e-05
# BLOCKSTACK_USDD_closeprice                    1.708306e-03
# EOS_STX_closeprice                            1.967648e-03
# ELROND-ERD-2_EOS_closeprice                   9.610875e-02
# INJECTIVE-PROTOCOL_EGLD_closeprice            1.526134e-02
# FRAX_INJ_closeprice                           1.532309e-05
# RENDER-TOKEN_FRAX_closeprice                  4.149715e-03
# NEO_RNDR_closeprice                           1.894901e-02
# AXIE-INFINITY_NEO_closeprice                  1.771664e-02
# ECASH_AXS_closeprice                          7.882054e-08
# GATECHAIN-TOKEN_XEC_closeprice                3.923722e-03
# COMPOUND-ETHER_GT_closeprice                  5.774514e-02
# PAXOS-STANDARD_CETH_closeprice                1.304765e-05
# FLOW_USDP_closeprice                          1.806364e-03
# APECOIN_FLOW_closeprice                       7.907412e-03
# KUCOIN-SHARES_APE_closeprice                  1.784962e-02
# CHILIZ_KCS_closeprice                         2.108662e-04
# IOTA_CHZ_closeprice                           2.655042e-04
#
#                                     MATIC-NETWORK_ADA_closeprice  \
# BITCOIN_BTC_closeprice                              1.496550e+02
# ETHEREUM_ETH_closeprice                             1.050749e+01
# LITECOIN_USDT_closeprice                            1.174641e+00
# TETHER_LTC_closeprice                               8.233890e-06
# BINANCECOIN_USDT_closeprice                         1.177787e+00
# CARDANO_BNB_closeprice                              2.180381e-03
# MATIC-NETWORK_ADA_closeprice                        7.898768e-03
# DOGECOIN_MATIC_closeprice                           3.721325e-04
# RIPPLE_DOGE_closeprice                              6.481046e-03
# BINANCE-USD_XRP_closeprice                          1.235614e-05
# THE-GRAPH_BUSD_closeprice                           1.115414e-03
# ALGORAND_GRT_closeprice                             7.434350e-04
# USDD_ALGO_closeprice                                7.327902e-05
# BLOCKSTACK_USDD_closeprice                          6.516441e-03
# EOS_STX_closeprice                                  7.075230e-03
# ELROND-ERD-2_EOS_closeprice                         3.613780e-01
# INJECTIVE-PROTOCOL_EGLD_closeprice                  5.513274e-02
# FRAX_INJ_closeprice                                 5.559929e-05
# RENDER-TOKEN_FRAX_closeprice                        1.612895e-02
# NEO_RNDR_closeprice                                 7.072896e-02
# AXIE-INFINITY_NEO_closeprice                        6.334491e-02
# ECASH_AXS_closeprice                                2.997518e-07
# GATECHAIN-TOKEN_XEC_closeprice                      1.477871e-02
# COMPOUND-ETHER_GT_closeprice                        2.110961e-01
# PAXOS-STANDARD_CETH_closeprice                      4.080984e-05
# FLOW_USDP_closeprice                                6.653993e-03
# APECOIN_FLOW_closeprice                             2.910317e-02
# KUCOIN-SHARES_APE_closeprice                        6.746042e-02
# CHILIZ_KCS_closeprice                               7.571524e-04
# IOTA_CHZ_closeprice                                 1.006437e-03
#
#                                     DOGECOIN_MATIC_closeprice  \
# BITCOIN_BTC_closeprice                           6.671179e+00
# ETHEREUM_ETH_closeprice                          5.056169e-01
# LITECOIN_USDT_closeprice                         5.212617e-02
# TETHER_LTC_closeprice                           -2.843159e-07
# BINANCECOIN_USDT_closeprice                      6.217442e-02
# CARDANO_BNB_closeprice                           1.154326e-04
# MATIC-NETWORK_ADA_closeprice                     3.721325e-04
# DOGECOIN_MATIC_closeprice                        3.256474e-05
# RIPPLE_DOGE_closeprice                           4.498065e-04
# BINANCE-USD_XRP_closeprice                       6.365174e-07
# THE-GRAPH_BUSD_closeprice                        4.972353e-05
# ALGORAND_GRT_closeprice                          3.335603e-05
# USDD_ALGO_closeprice                             2.964617e-06
# BLOCKSTACK_USDD_closeprice                       2.612409e-04
# EOS_STX_closeprice                               3.679232e-04
# ELROND-ERD-2_EOS_closeprice                      1.447702e-02
# INJECTIVE-PROTOCOL_EGLD_closeprice               2.192988e-03
# FRAX_INJ_closeprice                              2.622223e-06
# RENDER-TOKEN_FRAX_closeprice                     5.340848e-04
# NEO_RNDR_closeprice                              3.144340e-03
# AXIE-INFINITY_NEO_closeprice                     3.210259e-03
# ECASH_AXS_closeprice                             1.354736e-08
# GATECHAIN-TOKEN_XEC_closeprice                   6.104349e-04
# COMPOUND-ETHER_GT_closeprice                     1.011757e-02
# PAXOS-STANDARD_CETH_closeprice                   2.989226e-06
# FLOW_USDP_closeprice                             3.060956e-04
# APECOIN_FLOW_closeprice                          1.378791e-03
# KUCOIN-SHARES_APE_closeprice                     2.779242e-03
# CHILIZ_KCS_closeprice                            3.891848e-05
# IOTA_CHZ_closeprice                              4.078402e-05
#
#                                     RIPPLE_DOGE_closeprice  \
# BITCOIN_BTC_closeprice                        8.616405e+01
# ETHEREUM_ETH_closeprice                       7.040080e+00
# LITECOIN_USDT_closeprice                      6.422899e-01
# TETHER_LTC_closeprice                         5.989941e-06
# BINANCECOIN_USDT_closeprice                   8.725092e-01
# CARDANO_BNB_closeprice                        2.078787e-03
# MATIC-NETWORK_ADA_closeprice                  6.481046e-03
# DOGECOIN_MATIC_closeprice                     4.498065e-04
# RIPPLE_DOGE_closeprice                        1.053289e-02
# BINANCE-USD_XRP_closeprice                    1.525521e-05
# THE-GRAPH_BUSD_closeprice                     7.375008e-04
# ALGORAND_GRT_closeprice                       4.100047e-04
# USDD_ALGO_closeprice                          5.216670e-05
# BLOCKSTACK_USDD_closeprice                    2.996028e-03
# EOS_STX_closeprice                            5.486665e-03
# ELROND-ERD-2_EOS_closeprice                   2.198216e-01
# INJECTIVE-PROTOCOL_EGLD_closeprice            4.546772e-02
# FRAX_INJ_closeprice                           2.465509e-05
# RENDER-TOKEN_FRAX_closeprice                  7.337537e-03
# NEO_RNDR_closeprice                           4.308367e-02
# AXIE-INFINITY_NEO_closeprice                  4.958440e-02
# ECASH_AXS_closeprice                          1.517292e-07
# GATECHAIN-TOKEN_XEC_closeprice                8.157986e-03
# COMPOUND-ETHER_GT_closeprice                  1.413102e-01
# PAXOS-STANDARD_CETH_closeprice                4.822465e-05
# FLOW_USDP_closeprice                          4.456409e-03
# APECOIN_FLOW_closeprice                       1.761742e-02
# KUCOIN-SHARES_APE_closeprice                  3.495523e-02
# CHILIZ_KCS_closeprice                         5.640444e-04
# IOTA_CHZ_closeprice                           6.224912e-04
#
#                                     BINANCE-USD_XRP_closeprice  ...  \
# BITCOIN_BTC_closeprice                            1.649855e-01  ...
# ETHEREUM_ETH_closeprice                           1.154035e-02  ...
# LITECOIN_USDT_closeprice                          1.466593e-03  ...
# TETHER_LTC_closeprice                             2.150674e-07  ...
# BINANCECOIN_USDT_closeprice                       1.900135e-03  ...
# CARDANO_BNB_closeprice                            4.652408e-06  ...
# MATIC-NETWORK_ADA_closeprice                      1.235614e-05  ...
# DOGECOIN_MATIC_closeprice                         6.365174e-07  ...
# RIPPLE_DOGE_closeprice                            1.525521e-05  ...
# BINANCE-USD_XRP_closeprice                        5.632914e-07  ...
# THE-GRAPH_BUSD_closeprice                         1.312792e-06  ...
# ALGORAND_GRT_closeprice                           4.485096e-07  ...
# USDD_ALGO_closeprice                              5.012451e-07  ...
# BLOCKSTACK_USDD_closeprice                        6.621730e-06  ...
# EOS_STX_closeprice                                1.004085e-05  ...
# ELROND-ERD-2_EOS_closeprice                       4.450847e-04  ...
# INJECTIVE-PROTOCOL_EGLD_closeprice                9.751731e-05  ...
# FRAX_INJ_closeprice                               2.081701e-07  ...
# RENDER-TOKEN_FRAX_closeprice                      1.935227e-05  ...
# NEO_RNDR_closeprice                               9.510967e-05  ...
# AXIE-INFINITY_NEO_closeprice                      7.780757e-05  ...
# ECASH_AXS_closeprice                              5.055362e-10  ...
# GATECHAIN-TOKEN_XEC_closeprice                    1.732461e-05  ...
# COMPOUND-ETHER_GT_closeprice                      2.087060e-04  ...
# PAXOS-STANDARD_CETH_closeprice                    4.041740e-07  ...
# FLOW_USDP_closeprice                              9.732948e-06  ...
# APECOIN_FLOW_closeprice                           1.134853e-05  ...
# KUCOIN-SHARES_APE_closeprice                      5.761625e-05  ...
# CHILIZ_KCS_closeprice                             9.777548e-07  ...
# IOTA_CHZ_closeprice                               1.557283e-06  ...
#
#                                     AXIE-INFINITY_NEO_closeprice  \
# BITCOIN_BTC_closeprice                               1299.799326
# ETHEREUM_ETH_closeprice                                90.228733
# LITECOIN_USDT_closeprice                               10.300284
# TETHER_LTC_closeprice                                   0.000047
# BINANCECOIN_USDT_closeprice                             9.951916
# CARDANO_BNB_closeprice                                  0.017717
# MATIC-NETWORK_ADA_closeprice                            0.063345
# DOGECOIN_MATIC_closeprice                               0.003210
# RIPPLE_DOGE_closeprice                                  0.049584
# BINANCE-USD_XRP_closeprice                              0.000078
# THE-GRAPH_BUSD_closeprice                               0.009395
# ALGORAND_GRT_closeprice                                 0.006841
# USDD_ALGO_closeprice                                    0.000616
# BLOCKSTACK_USDD_closeprice                              0.057866
# EOS_STX_closeprice                                      0.060396
# ELROND-ERD-2_EOS_closeprice                             3.056154
# INJECTIVE-PROTOCOL_EGLD_closeprice                      0.458600
# FRAX_INJ_closeprice                                     0.000504
# RENDER-TOKEN_FRAX_closeprice                            0.139939
# NEO_RNDR_closeprice                                     0.611286
# AXIE-INFINITY_NEO_closeprice                            0.548906
# ECASH_AXS_closeprice                                    0.000003
# GATECHAIN-TOKEN_XEC_closeprice                          0.126143
# COMPOUND-ETHER_GT_closeprice                            1.812858
# PAXOS-STANDARD_CETH_closeprice                          0.000336
# FLOW_USDP_closeprice                                    0.057947
# APECOIN_FLOW_closeprice                                 0.258019
# KUCOIN-SHARES_APE_closeprice                            0.604057
# CHILIZ_KCS_closeprice                                   0.006506
# IOTA_CHZ_closeprice                                     0.008043
#
#                                     ECASH_AXS_closeprice  \
# BITCOIN_BTC_closeprice                      6.742531e-03
# ETHEREUM_ETH_closeprice                     4.499278e-04
# LITECOIN_USDT_closeprice                    5.925816e-05
# TETHER_LTC_closeprice                       2.859483e-10
# BINANCECOIN_USDT_closeprice                 4.909629e-05
# CARDANO_BNB_closeprice                      7.882054e-08
# MATIC-NETWORK_ADA_closeprice                2.997518e-07
# DOGECOIN_MATIC_closeprice                   1.354736e-08
# RIPPLE_DOGE_closeprice                      1.517292e-07
# BINANCE-USD_XRP_closeprice                  5.055362e-10
# THE-GRAPH_BUSD_closeprice                   4.871656e-08
# ALGORAND_GRT_closeprice                     3.308457e-08
# USDD_ALGO_closeprice                        3.599834e-09
# BLOCKSTACK_USDD_closeprice                  2.982327e-07
# EOS_STX_closeprice                          3.021925e-07
# ELROND-ERD-2_EOS_closeprice                 1.567934e-05
# INJECTIVE-PROTOCOL_EGLD_closeprice          2.304364e-06
# FRAX_INJ_closeprice                         2.768230e-09
# RENDER-TOKEN_FRAX_closeprice                7.650962e-07
# NEO_RNDR_closeprice                         3.322334e-06
# AXIE-INFINITY_NEO_closeprice                2.628310e-06
# ECASH_AXS_closeprice                        1.885577e-11
# GATECHAIN-TOKEN_XEC_closeprice              6.676307e-07
# COMPOUND-ETHER_GT_closeprice                9.068399e-06
# PAXOS-STANDARD_CETH_closeprice              1.147948e-09
# FLOW_USDP_closeprice                        3.159392e-07
# APECOIN_FLOW_closeprice                     1.181194e-06
# KUCOIN-SHARES_APE_closeprice                3.138045e-06
# CHILIZ_KCS_closeprice                       3.105588e-08
# IOTA_CHZ_closeprice                         4.133570e-08
#
#                                     GATECHAIN-TOKEN_XEC_closeprice  \
# BITCOIN_BTC_closeprice                                3.300535e+02
# ETHEREUM_ETH_closeprice                               2.212048e+01
# LITECOIN_USDT_closeprice                              2.677125e+00
# TETHER_LTC_closeprice                                 2.041210e-05
# BINANCECOIN_USDT_closeprice                           2.342755e+00
# CARDANO_BNB_closeprice                                3.923722e-03
# MATIC-NETWORK_ADA_closeprice                          1.477871e-02
# DOGECOIN_MATIC_closeprice                             6.104349e-04
# RIPPLE_DOGE_closeprice                                8.157986e-03
# BINANCE-USD_XRP_closeprice                            1.732461e-05
# THE-GRAPH_BUSD_closeprice                             2.337607e-03
# ALGORAND_GRT_closeprice                               1.736826e-03
# USDD_ALGO_closeprice                                  1.603601e-04
# BLOCKSTACK_USDD_closeprice                            1.534208e-02
# EOS_STX_closeprice                                    1.426690e-02
# ELROND-ERD-2_EOS_closeprice                           7.792708e-01
# INJECTIVE-PROTOCOL_EGLD_closeprice                    1.074830e-01
# FRAX_INJ_closeprice                                   1.255297e-04
# RENDER-TOKEN_FRAX_closeprice                          3.893362e-02
# NEO_RNDR_closeprice                                   1.562814e-01
# AXIE-INFINITY_NEO_closeprice                          1.261432e-01
# ECASH_AXS_closeprice                                  6.676307e-07
# GATECHAIN-TOKEN_XEC_closeprice                        3.393484e-02
# COMPOUND-ETHER_GT_closeprice                          4.447106e-01
# PAXOS-STANDARD_CETH_closeprice                        6.599516e-05
# FLOW_USDP_closeprice                                  1.424074e-02
# APECOIN_FLOW_closeprice                               6.287068e-02
# KUCOIN-SHARES_APE_closeprice                          1.544282e-01
# CHILIZ_KCS_closeprice                                 1.527965e-03
# IOTA_CHZ_closeprice                                   2.232650e-03
#
#                                     COMPOUND-ETHER_GT_closeprice  \
# BITCOIN_BTC_closeprice                               4572.410681
# ETHEREUM_ETH_closeprice                               313.227230
# LITECOIN_USDT_closeprice                               35.794438
# TETHER_LTC_closeprice                                   0.000141
# BINANCECOIN_USDT_closeprice                            34.032261
# CARDANO_BNB_closeprice                                  0.057745
# MATIC-NETWORK_ADA_closeprice                            0.211096
# DOGECOIN_MATIC_closeprice                               0.010118
# RIPPLE_DOGE_closeprice                                  0.141310
# BINANCE-USD_XRP_closeprice                              0.000209
# THE-GRAPH_BUSD_closeprice                               0.032061
# ALGORAND_GRT_closeprice                                 0.023806
# USDD_ALGO_closeprice                                    0.002017
# BLOCKSTACK_USDD_closeprice                              0.205700
# EOS_STX_closeprice                                      0.202406
# ELROND-ERD-2_EOS_closeprice                            10.571962
# INJECTIVE-PROTOCOL_EGLD_closeprice                      1.484056
# FRAX_INJ_closeprice                                     0.001659
# RENDER-TOKEN_FRAX_closeprice                            0.498286
# NEO_RNDR_closeprice                                     2.108389
# AXIE-INFINITY_NEO_closeprice                            1.812858
# ECASH_AXS_closeprice                                    0.000009
# GATECHAIN-TOKEN_XEC_closeprice                          0.444711
# COMPOUND-ETHER_GT_closeprice                            6.301059
# PAXOS-STANDARD_CETH_closeprice                          0.001041
# FLOW_USDP_closeprice                                    0.194115
# APECOIN_FLOW_closeprice                                 0.892506
# KUCOIN-SHARES_APE_closeprice                            2.098362
# CHILIZ_KCS_closeprice                                   0.021914
# IOTA_CHZ_closeprice                                     0.028742
#
#                                     PAXOS-STANDARD_CETH_closeprice  \
# BITCOIN_BTC_closeprice                                6.851408e-01
# ETHEREUM_ETH_closeprice                               5.420603e-02
# LITECOIN_USDT_closeprice                              5.039497e-03
# TETHER_LTC_closeprice                                 1.741272e-07
# BINANCECOIN_USDT_closeprice                           7.135291e-03
# CARDANO_BNB_closeprice                                1.304765e-05
# MATIC-NETWORK_ADA_closeprice                          4.080984e-05
# DOGECOIN_MATIC_closeprice                             2.989226e-06
# RIPPLE_DOGE_closeprice                                4.822465e-05
# BINANCE-USD_XRP_closeprice                            4.041740e-07
# THE-GRAPH_BUSD_closeprice                             5.373836e-06
# ALGORAND_GRT_closeprice                               2.549532e-06
# USDD_ALGO_closeprice                                  7.035437e-07
# BLOCKSTACK_USDD_closeprice                            3.229215e-05
# EOS_STX_closeprice                                    3.695356e-05
# ELROND-ERD-2_EOS_closeprice                           1.729852e-03
# INJECTIVE-PROTOCOL_EGLD_closeprice                    2.786745e-04
# FRAX_INJ_closeprice                                   2.867113e-07
# RENDER-TOKEN_FRAX_closeprice                          5.759672e-05
# NEO_RNDR_closeprice                                   3.222209e-04
# AXIE-INFINITY_NEO_closeprice                          3.363265e-04
# ECASH_AXS_closeprice                                  1.147948e-09
# GATECHAIN-TOKEN_XEC_closeprice                        6.599516e-05
# COMPOUND-ETHER_GT_closeprice                          1.041495e-03
# PAXOS-STANDARD_CETH_closeprice                        2.475309e-06
# FLOW_USDP_closeprice                                  3.103001e-05
# APECOIN_FLOW_closeprice                               1.377458e-04
# KUCOIN-SHARES_APE_closeprice                          2.888735e-04
# CHILIZ_KCS_closeprice                                 4.414892e-06
# IOTA_CHZ_closeprice                                   4.336113e-06
#
#                                     FLOW_USDP_closeprice  \
# BITCOIN_BTC_closeprice                      1.419427e+02
# ETHEREUM_ETH_closeprice                     9.639586e+00
# LITECOIN_USDT_closeprice                    1.176894e+00
# TETHER_LTC_closeprice                       6.944230e-06
# BINANCECOIN_USDT_closeprice                 1.051069e+00
# CARDANO_BNB_closeprice                      1.806364e-03
# MATIC-NETWORK_ADA_closeprice                6.653993e-03
# DOGECOIN_MATIC_closeprice                   3.060956e-04
# RIPPLE_DOGE_closeprice                      4.456409e-03
# BINANCE-USD_XRP_closeprice                  9.732948e-06
# THE-GRAPH_BUSD_closeprice                   1.047391e-03
# ALGORAND_GRT_closeprice                     7.490732e-04
# USDD_ALGO_closeprice                        7.354337e-05
# BLOCKSTACK_USDD_closeprice                  6.427121e-03
# EOS_STX_closeprice                          6.470130e-03
# ELROND-ERD-2_EOS_closeprice                 3.372011e-01
# INJECTIVE-PROTOCOL_EGLD_closeprice          5.117191e-02
# FRAX_INJ_closeprice                         5.475511e-05
# RENDER-TOKEN_FRAX_closeprice                1.616668e-02
# NEO_RNDR_closeprice                         6.843776e-02
# AXIE-INFINITY_NEO_closeprice                5.794661e-02
# ECASH_AXS_closeprice                        3.159392e-07
# GATECHAIN-TOKEN_XEC_closeprice              1.424074e-02
# COMPOUND-ETHER_GT_closeprice                1.941153e-01
# PAXOS-STANDARD_CETH_closeprice              3.103001e-05
# FLOW_USDP_closeprice                        6.702388e-03
# APECOIN_FLOW_closeprice                     2.695346e-02
# KUCOIN-SHARES_APE_closeprice                6.672866e-02
# CHILIZ_KCS_closeprice                       6.848347e-04
# IOTA_CHZ_closeprice                         9.007501e-04
#
#                                     APECOIN_FLOW_closeprice  \
# BITCOIN_BTC_closeprice                           639.795265
# ETHEREUM_ETH_closeprice                           44.453386
# LITECOIN_USDT_closeprice                           5.002083
# TETHER_LTC_closeprice                              0.000008
# BINANCECOIN_USDT_closeprice                        4.685825
# CARDANO_BNB_closeprice                             0.007907
# MATIC-NETWORK_ADA_closeprice                       0.029103
# DOGECOIN_MATIC_closeprice                          0.001379
# RIPPLE_DOGE_closeprice                             0.017617
# BINANCE-USD_XRP_closeprice                         0.000011
# THE-GRAPH_BUSD_closeprice                          0.004461
# ALGORAND_GRT_closeprice                            0.003557
# USDD_ALGO_closeprice                               0.000241
# BLOCKSTACK_USDD_closeprice                         0.030307
# EOS_STX_closeprice                                 0.028388
# ELROND-ERD-2_EOS_closeprice                        1.506105
# INJECTIVE-PROTOCOL_EGLD_closeprice                 0.202285
# FRAX_INJ_closeprice                                0.000276
# RENDER-TOKEN_FRAX_closeprice                       0.068629
# NEO_RNDR_closeprice                                0.293159
# AXIE-INFINITY_NEO_closeprice                       0.258019
# ECASH_AXS_closeprice                               0.000001
# GATECHAIN-TOKEN_XEC_closeprice                     0.062871
# COMPOUND-ETHER_GT_closeprice                       0.892506
# PAXOS-STANDARD_CETH_closeprice                     0.000138
# FLOW_USDP_closeprice                               0.026953
# APECOIN_FLOW_closeprice                            0.141260
# KUCOIN-SHARES_APE_closeprice                       0.310717
# CHILIZ_KCS_closeprice                              0.003157
# IOTA_CHZ_closeprice                                0.003967
#
#                                     KUCOIN-SHARES_APE_closeprice  \
# BITCOIN_BTC_closeprice                               1595.797678
# ETHEREUM_ETH_closeprice                               104.375700
# LITECOIN_USDT_closeprice                               12.534036
# TETHER_LTC_closeprice                                   0.000068
# BINANCECOIN_USDT_closeprice                            10.923334
# CARDANO_BNB_closeprice                                  0.017850
# MATIC-NETWORK_ADA_closeprice                            0.067460
# DOGECOIN_MATIC_closeprice                               0.002779
# RIPPLE_DOGE_closeprice                                  0.034955
# BINANCE-USD_XRP_closeprice                              0.000058
# THE-GRAPH_BUSD_closeprice                               0.010939
# ALGORAND_GRT_closeprice                                 0.008612
# USDD_ALGO_closeprice                                    0.000717
# BLOCKSTACK_USDD_closeprice                              0.074254
# EOS_STX_closeprice                                      0.066440
# ELROND-ERD-2_EOS_closeprice                             3.719816
# INJECTIVE-PROTOCOL_EGLD_closeprice                      0.510900
# FRAX_INJ_closeprice                                     0.000634
# RENDER-TOKEN_FRAX_closeprice                            0.185636
# NEO_RNDR_closeprice                                     0.730480
# AXIE-INFINITY_NEO_closeprice                            0.604057
# ECASH_AXS_closeprice                                    0.000003
# GATECHAIN-TOKEN_XEC_closeprice                          0.154428
# COMPOUND-ETHER_GT_closeprice                            2.098362
# PAXOS-STANDARD_CETH_closeprice                          0.000289
# FLOW_USDP_closeprice                                    0.066729
# APECOIN_FLOW_closeprice                                 0.310717
# KUCOIN-SHARES_APE_closeprice                            0.785227
# CHILIZ_KCS_closeprice                                   0.007353
# IOTA_CHZ_closeprice                                     0.008886
#
#                                     CHILIZ_KCS_closeprice  IOTA_CHZ_closeprice
# BITCOIN_BTC_closeprice                       1.577749e+01         2.094310e+01
# ETHEREUM_ETH_closeprice                      1.092071e+00         1.425124e+00
# LITECOIN_USDT_closeprice                     1.234000e-01         1.701630e-01
# TETHER_LTC_closeprice                        3.729803e-07         2.157407e-06
# BINANCECOIN_USDT_closeprice                  1.207696e-01         1.532907e-01
# CARDANO_BNB_closeprice                       2.108662e-04         2.655042e-04
# MATIC-NETWORK_ADA_closeprice                 7.571524e-04         1.006437e-03
# DOGECOIN_MATIC_closeprice                    3.891848e-05         4.078402e-05
# RIPPLE_DOGE_closeprice                       5.640444e-04         6.224912e-04
# BINANCE-USD_XRP_closeprice                   9.777548e-07         1.557283e-06
# THE-GRAPH_BUSD_closeprice                    1.131615e-04         1.471641e-04
# ALGORAND_GRT_closeprice                      8.247987e-05         1.092796e-04
# USDD_ALGO_closeprice                         7.184061e-06         1.099290e-05
# BLOCKSTACK_USDD_closeprice                   7.077913e-04         9.815097e-04
# EOS_STX_closeprice                           7.241139e-04         9.605239e-04
# ELROND-ERD-2_EOS_closeprice                  3.706491e-02         4.914400e-02
# INJECTIVE-PROTOCOL_EGLD_closeprice           5.347067e-03         6.629529e-03
# FRAX_INJ_closeprice                          6.403992e-06         6.238035e-06
# RENDER-TOKEN_FRAX_closeprice                 1.680984e-03         2.541102e-03
# NEO_RNDR_closeprice                          7.314790e-03         1.054467e-02
# AXIE-INFINITY_NEO_closeprice                 6.505958e-03         8.043151e-03
# ECASH_AXS_closeprice                         3.105588e-08         4.133570e-08
# GATECHAIN-TOKEN_XEC_closeprice               1.527965e-03         2.232650e-03
# COMPOUND-ETHER_GT_closeprice                 2.191422e-02         2.874224e-02
# PAXOS-STANDARD_CETH_closeprice               4.414892e-06         4.336113e-06
# FLOW_USDP_closeprice                         6.848347e-04         9.007501e-04
# APECOIN_FLOW_closeprice                      3.156940e-03         3.967458e-03
# KUCOIN-SHARES_APE_closeprice                 7.352528e-03         8.885590e-03
# CHILIZ_KCS_closeprice                        7.927089e-05         9.665174e-05
# IOTA_CHZ_closeprice                          9.665174e-05         2.070645e-04
#
# [30 rows x 30 columns]

# %% [markdown]
# 3. Use the function in the video to generate a complete crypto portfolio for $10,000.

# %%
def simulate_portfolios(df, num_portfolios, mean_daily_returns, cov_matrix):
    num_assets = len(df.columns)
    results = np.zeros((3, num_portfolios))
    
    for i in range(num_portfolios):
        weights = np.random.random(num_assets)
        weights /= np.sum(weights)
        
        # Expected portfolio return
        portfolio_return = np.sum(mean_daily_returns * weights) * 252
        
        # Expected portfolio volatility
        portfolio_stddev = np.sqrt(np.dot(weights.T, np.dot(cov_matrix * 252, weights)))
        
        # Store results in results array
        results[0,i] = portfolio_return
        results[1,i] = portfolio_stddev
        
        # Portfolio Sharpe ratio, assuming risk-free rate is close to 0
        results[2,i] = results[0,i] / results[1,i]
    
    return results

# %%
num_portfolios = 10000
results = simulate_portfolios(coins_df, num_portfolios, coin_mean, coin_cov)
print(results)
# Out:
# [[2.52202361e+05 1.80507172e+05 2.76710212e+04 ... 4.05873212e+05
#   2.41608565e+05 4.31838609e+05]
#  [1.06064336e+03 7.60682339e+02 1.23442454e+02 ... 1.70004740e+03
#   1.01836523e+03 1.81073766e+03]
#  [2.37782434e+02 2.37296388e+02 2.24161302e+02 ... 2.38742292e+02
#   2.37251389e+02 2.38487671e+02]]

# %% [markdown]
# ### 4       Locate the Best portfolios
# The percentages returned from the best portfolio search represent the total assets added to each coin from the $10,000.
#
# 4.1        Locate the position of the portfolio with the highest Sharpe Ratio

# %% [markdown]
# 4.2        Locate the portfolio with the lowest volatility

# %% [markdown]
# 4.3        Plot the efficient portfolio
